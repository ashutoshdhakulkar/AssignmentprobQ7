# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Q7.csv")

# %%
df
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0             Mazda RX4    3.90  2.620  16.46
# 1         Mazda RX4 Wag    3.90  2.875  17.02
# 2            Datsun 710    3.85  2.320  18.61
# 3        Hornet 4 Drive    3.08  3.215  19.44
# 4     Hornet Sportabout    3.15  3.440  17.02
# 5               Valiant    2.76  3.460  20.22
# 6            Duster 360    3.21  3.570  15.84
# 7             Merc 240D    3.69  3.190  20.00
# 8              Merc 230    3.92  3.150  22.90
# 9              Merc 280    3.92  3.440  18.30
# 10            Merc 280C    3.92  3.440  18.90
# 11           Merc 450SE    3.07  4.070  17.40
# 12           Merc 450SL    3.07  3.730  17.60
# 13          Merc 450SLC    3.07  3.780  18.00
# 14   Cadillac Fleetwood    2.93  5.250  17.98
# 15  Lincoln Continental    3.00  5.424  17.82
# 16    Chrysler Imperial    3.23  5.345  17.42
# 17             Fiat 128    4.08  2.200  19.47
# 18          Honda Civic    4.93  1.615  18.52
# ...

# %%
df.Points.mean()
# Out:
# 3.5965625

# %%
df.Score.mean()
# Out:
# 3.2172500000000004

# %%
df.Weigh.mean()
# Out:
# 17.848750000000003

# %%
df.Points.median()
# Out:
# 3.6950000000000003

# %%
df.Score.median()
# Out:
# 3.325

# %%
df.Weigh.median()
# Out:
# 17.71

# %%
df.Points.mode()
# Out:
# 0    3.07
# 1    3.92
# Name: Points, dtype: float64

# %%
df.Score.mode()
# Out:
# 0    3.44
# Name: Score, dtype: float64

# %%
df.Weigh.mode()
# Out:
# 0    17.02
# 1    18.90
# Name: Weigh, dtype: float64

# %%
df.Points.var()
# Out:
# 0.2858813508064516

# %%
df.Score.var()
# Out:
# 0.9573789677419354

# %%
df.Weigh.var()
# Out:
# 3.193166129032258

# %%
df.Points.std()
# Out:
# 0.5346787360709715

# %%
df.Score.std()
# Out:
# 0.9784574429896966

# %%
df.Weigh.std()
# Out:
# 1.7869432360968431

# %%
print("The range for Points column is :",df.Points.max()-df.Points.min())
# Out:
# The range for Points column is : 2.17

# %%
print("The range for Score column is :",df.Score.max()-df.Score.min())
# Out:
# The range for Score column is : 3.9110000000000005

# %%
print("The range for Weigh column is:",df.Weigh.max()-df.Weigh.min())
# Out:
# The range for Weigh column is: 8.399999999999999
