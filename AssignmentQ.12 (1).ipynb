# %%
list=[34,36,36,38,38,39,39,40,40,41,41,41,41,42,42,45,49,56]
list
# Out:
# [34, 36, 36, 38, 38, 39, 39, 40, 40, 41, 41, 41, 41, 42, 42, 45, 49, 56]

# %%
total=sum(list)

# %%
length=len(list)

# %%
result= total/length
print("The mean will be : ",result)
# Out:
# The mean will be :  41.0

# %%
list.sort()

# %%
if len(list)%2 == 0:
  n1=list[len(list)//2]
  n2=list[len(list)//2-1]
  median = (n1+n2)/2
else:
  median=list[len(list)/2]

# %%
print(median)
# Out:
# 40.5

# %%
import statistics

# %%
list
# Out:
# [34, 36, 36, 38, 38, 39, 39, 40, 40, 41, 41, 41, 41, 42, 42, 45, 49, 56]

# %%
variance= statistics.variance(list)
print(variance)
# Out:
# 25.529411764705884

# %%
stdev= statistics.stdev(list)
print(stdev)
# Out:
# 5.05266382858645
